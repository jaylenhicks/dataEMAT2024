# %% [markdown]
# # Jaylen Hicks
# ## Analysis Plan

# %% [markdown]
# I plan to take the Most Popular Marvel Franchise: Avengers, First Marvel Franchise: Iron Man, and Most Recent Franchise: Venom, and comparing the budget and revenue of each film in its sequence to see if they falling out of favor with audiences, by seeing if there was an increase or decrease in box office performance based. I will create a chart of each film's revenue vs budget first. Then I will create a chart comparing the box office performance of each film in the sequence. I will do this for each film.

# %%
import requests
import base64
import six
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjNjI4YjAwOGQxODllNmIwZTgwZTgwZTU2OTgxNWVlYSIsIm5iZiI6MTczMjM4NjI1Mi4wNDcxNjU0LCJzdWIiOiI2NzQyMWQyMDdiODI1ZTY4NWI0ZTY1ODUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.tLFCB56hri3IvH_2lFKNIaS4ZEODf0mmIxbIgW-vVC4"
}

# %% [markdown]
# ## Venom Series 2021-Present

# %%
Venom_1 = "https://api.themoviedb.org/3/movie/335983?language=en-US"
response = requests.get(Venom_1, headers=headers)
print(response.text)
Venom_1= response.text
# Out:
# {"adult":false,"backdrop_path":"/VuukZLgaCrho2Ar8Scl9HtV3yD.jpg","belongs_to_collection":{"id":558216,"name":"Venom Collection","poster_path":"/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg","backdrop_path":"/vq340s8DxA5Q209FT8PHA6CXYOx.jpg"},"budget":116000000,"genres":[{"id":878,"name":"Science Fiction"},{"id":28,"name":"Action"}],"homepage":"https://www.sonypictures.com/movies/venom","id":335983,"imdb_id":"tt1270797","origin_country":["US"],"original_language":"en","original_title":"Venom","overview":"Investigative journalist Eddie Brock attempts a comeback following a scandal, but accidentally becomes the host of Venom, a violent, super powerful alien symbiote. Soon, he must rely on his newfound powers to protect the world from a shadowy organization looking for a symbiote of their own.","popularity":301.84,"poster_path":"/2uNW4WbgBXL25BAbXGLnLqX71Sw.jpg","production_companies":[{"id":53462,"logo_path":"/nx8B3Phlcse02w86RW4CJqzCnfL.png","name":"Matt Tolmach Productions","origin_country":"US"},
# ...

# %%
Venom_1 = {
    "adult": False,
    "backdrop_path": "/VuukZLgaCrho2Ar8Scl9HtV3yD.jpg",
    "belongs_to_collection": {
        "id": 558216,
        "name": "Venom Collection",
        "poster_path": "/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg",
        "backdrop_path": "/vq340s8DxA5Q209FT8PHA6CXYOx.jpg"
    },
    "budget": 116000000,
    "genres": [{"id": 878, "name": "Science Fiction"}, {"id": 28, "name": "Action"}],
    "homepage": "https://www.sonypictures.com/movies/venom",
    "id": 335983,
    "imdb_id": "tt1270797",
    "origin_country": ["US"],
    "original_language": "en",
    "original_title": "Venom",
    "overview": "Investigative journalist Eddie Brock attempts a comeback following a scandal, but accidentally becomes the host of Venom, a violent, super powerful alien symbiote. Soon, he must rely on his newfound powers to protect the world from a shadowy organization looking for a symbiote of their own.",
    "popularity": 301.84,
    "poster_path": "/2uNW4WbgBXL25BAbXGLnLqX71Sw.jpg",
    "production_companies": [
        {"id": 53462, "logo_path": "/nx8B3Phlcse02w86RW4CJqzCnfL.png", "name": "Matt Tolmach Productions", "origin_country": "US"},
        {"id": 84041, "logo_path": "/nw4kyc29QRpNtFbdsBHkRSFavvt.png", "name": "Pascal Pictures", "origin_country": "US"},
        {"id": 7505, "logo_path": "/837VMM4wOkODc1idNxGT0KQJlej.png", "name": "Marvel Entertainment", "origin_country": "US"},
        {"id": 81620, "logo_path": "/7LkIVuWBVScdujpKhBPx1TMnPQE.png", "name": "Tencent Pictures", "origin_country": "CN"},
        {"id": 14439, "logo_path": None, "name": "Arad Productions", "origin_country": "US"},
        {"id": 5, "logo_path": "/71BqEFAF4V3qjjMPCpLuyJFB9A.png", "name": "Columbia Pictures", "origin_country": "US"}
    ],
    "production_countries": [
        {"iso_3166_1": "CN", "name": "China"},
        {"iso_3166_1": "US", "name": "United States of America"}
    ],
    "release_date": "2018-09-28",
    "revenue": 856085151,
    "runtime": 112,
    "spoken_languages": [
        {"english_name": "Mandarin", "iso_639_1": "zh", "name": "普通话"},
        {"english_name": "English", "iso_639_1": "en", "name": "English"},
        {"english_name": "Malay", "iso_639_1": "ms", "name": "Bahasa melayu"}
    ],
    "status": "Released",
    "tagline": "The world has enough Superheroes.",
    "title": "Venom",
    "video": False,
    "vote_average": 6.8,
    "vote_count": 16066
}

budget = Venom_1['budget']
revenue = Venom_1['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['black', 'red'])
plt.title('Budget vs Revenue for the First Venom Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %%
Venom_2 = "https://api.themoviedb.org/3/movie/580489?language=en-US"
response = requests.get(Venom_2, headers=headers)
print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg","belongs_to_collection":{"id":558216,"name":"Venom Collection","poster_path":"/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg","backdrop_path":"/vq340s8DxA5Q209FT8PHA6CXYOx.jpg"},"budget":110000000,"genres":[{"id":878,"name":"Science Fiction"},{"id":28,"name":"Action"},{"id":12,"name":"Adventure"}],"homepage":"https://www.venom.movie","id":580489,"imdb_id":"tt7097896","origin_country":["US"],"original_language":"en","original_title":"Venom: Let There Be Carnage","overview":"After finding a host body in investigative reporter Eddie Brock, the alien symbiote must face a new enemy, Carnage, the alter ego of serial killer Cletus Kasady.","popularity":341.095,"poster_path":"/1MJNcPZy46hIy2CmSqOeru0yr5C.jpg","production_companies":[{"id":5,"logo_path":"/71BqEFAF4V3qjjMPCpLuyJFB9A.png","name":"Columbia Pictures","origin_country":"US"},{"id":84041,"logo_path":"/nw4kyc29QRpNtFbdsBHkRSFavvt.png","name":"Pascal Pictures","origin_country":"US"},
# ...

# %%
Venom_2 = {
    "adult": False,
    "backdrop_path": "/vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg",
    "belongs_to_collection": {
        "id": 558216,
        "name": "Venom Collection",
        "poster_path": "/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg",
        "backdrop_path": "/vq340s8DxA5Q209FT8PHA6CXYOx.jpg"
    },
    "budget": 110000000,
    "genres": [
        {"id": 878, "name": "Science Fiction"},
        {"id": 28, "name": "Action"},
        {"id": 12, "name": "Adventure"}
    ],
    "homepage": "https://www.venom.movie",
    "id": 580489,
    "imdb_id": "tt7097896",
    "origin_country": ["US"],
    "original_language": "en",
    "original_title": "Venom: Let There Be Carnage",
    "overview": "After finding a host body in investigative reporter Eddie Brock, the alien symbiote must face a new enemy, Carnage, the alter ego of serial killer Cletus Kasady.",
    "popularity": 341.095,
    "poster_path": "/1MJNcPZy46hIy2CmSqOeru0yr5C.jpg",
    "production_companies": [
        {"id": 5, "logo_path": "/71BqEFAF4V3qjjMPCpLuyJFB9A.png", "name": "Columbia Pictures", "origin_country": "US"},
        {"id": 84041, "logo_path": "/nw4kyc29QRpNtFbdsBHkRSFavvt.png", "name": "Pascal Pictures", "origin_country": "US"},
        {"id": 53462, "logo_path": "/nx8B3Phlcse02w86RW4CJqzCnfL.png", "name": "Matt Tolmach Productions", "origin_country": "US"},
        {"id": 14439, "logo_path": None, "name": "Arad Productions", "origin_country": "US"}
    ],
    "production_countries": [{"iso_3166_1": "US", "name": "United States of America"}],
    "release_date": "2021-09-30",
    "revenue": 506863592,
    "runtime": 97,
    "spoken_languages": [
        {"english_name": "English", "iso_639_1": "en", "name": "English"},
        {"english_name": "Spanish", "iso_639_1": "es", "name": "Español"}
    ],
    "status": "Released",
    "tagline": "It’s time to meet Carnage.",
    "title": "Venom: Let There Be Carnage",
    "video": False,
    "vote_average": 6.8,
    "vote_count": 10268
}

# Accessing data
budget = Venom_2['budget']
revenue = Venom_2['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['black', 'red'])
plt.title('Budget vs Revenue for The Second Venom Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %%
Venom_3 = "https://api.themoviedb.org/3/movie/912649?language=en-US"
response = requests.get(Venom_3, headers=headers)
print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg","belongs_to_collection":{"id":558216,"name":"Venom Collection","poster_path":"/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg","backdrop_path":"/vq340s8DxA5Q209FT8PHA6CXYOx.jpg"},"budget":120000000,"genres":[{"id":28,"name":"Action"},{"id":878,"name":"Science Fiction"},{"id":12,"name":"Adventure"}],"homepage":"https://venom.movie","id":912649,"imdb_id":"tt16366836","origin_country":["US"],"original_language":"en","original_title":"Venom: The Last Dance","overview":"Eddie and Venom are on the run. Hunted by both of their worlds and with the net closing in, the duo are forced into a devastating decision that will bring the curtains down on Venom and Eddie's last dance.","popularity":12656.263,"poster_path":"/aosm8NMQ3UyoBVpSxyimorCQykC.jpg","production_companies":[{"id":5,"logo_path":"/71BqEFAF4V3qjjMPCpLuyJFB9A.png","name":"Columbia Pictures","origin_country":"US"},{"id":84041,"logo_path":"/nw4kyc29QRpNtFbdsBHkRSFavvt.png","name":"Pas
# ...

# %%
Venom_3={
  "adult": False,
  "backdrop_path": "/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg",
  "belongs_to_collection": {
    "id": 558216,
    "name": "Venom Collection",
    "poster_path": "/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg",
    "backdrop_path": "/vq340s8DxA5Q209FT8PHA6CXYOx.jpg"
  },
  "budget": 120000000,
  "genres": [
    {
      "id": 28,
      "name": "Action"
    },
    {
      "id": 878,
      "name": "Science Fiction"
    },
    {
      "id": 12,
      "name": "Adventure"
    }
  ],
  "homepage": "https://venom.movie",
  "id": 912649,
  "imdb_id": "tt16366836",
  "origin_country": [
    "US"
  ],
  "original_language": "en",
  "original_title": "Venom: The Last Dance",
  "overview": "Eddie and Venom are on the run. Hunted by both of their worlds and with the net closing in, the duo are forced into a devastating decision that will bring the curtains down on Venom and Eddie's last dance.",
  "popularity": 12656.263,
  "poster_path": "/aosm8NMQ3UyoBVpSxyimorCQykC.jpg",
  "production_companies": [
    {
      "id": 5,
      "logo_path": "/71BqEFAF4V3qjjMPCpLuyJFB9A.png",
      "name": "Columbia Pictures",
      "origin_country": "US"
    },
    {
      "id": 84041,
      "logo_path": "/nw4kyc29QRpNtFbdsBHkRSFavvt.png",
      "name": "Pascal Pictures",
      "origin_country": "US"
    },
    {
      "id": 53462,
      "logo_path": "/nx8B3Phlcse02w86RW4CJqzCnfL.png",
      "name": "Matt Tolmach Productions",
      "origin_country": "US"
    },
    {
      "id": 91797,
      "name": "Hutch Parker Entertainment",
      "origin_country": "US"
    },
    {
      "id": 14439,
      "name": "Arad Productions",
      "origin_country": "US"
    }
  ],
  "production_countries": [
    {
      "iso_3166_1": "US",
      "name": "United States of America"
    }
  ],
  "release_date": "2024-10-22",
  "revenue": 468513700,
  "runtime": 109,
  "spoken_languages": [
    {
      "english_name": "English",
      "iso_639_1": "en",
      "name": "English"
    }
  ],
  "status": "Released",
  "tagline": "'Til death do they part.",
  "title": "Venom: The Last Dance",
  "video": False,
  "vote_average": 6.6,
  "vote_count": 1128
}

# Accessing data
budget = Venom_3['budget']
revenue = Venom_3['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['black', 'red'])
plt.title('Budget vs Revenue for the Third Venom Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()
