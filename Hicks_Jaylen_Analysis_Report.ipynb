# %% [markdown]
# # Jaylen Hicks
# ## Analysis Report
# ### November 22, 2024

# %% [markdown]
# My favorite album is Access All Areas by Flo. I have followed this group since their first single "Cardboard Box" released in 2022. Their music brings back Y2K sound of R&B, like Destiny's Child SWV and other groups before them. Their ability to harmonize and modernize nostalgic sounds created a no-skip album full of great songs. Although this is their debut album, I have no doubts that they will be one of the most successful groups in music history as they progress further into their carrer.

# %% [markdown]
# My second favorite album is Ungodly Hour by Chloe x Halle. There is something about a group, or in this case, a sister duo that gives me the case of earworm. Chloe and Halle's style of music is definetly in a category of its own. With it's destinct sound of alternative R&B, their very different but complementary vocals, personality, and interest shine on this album. They're great on their own, but definetly a force to recokon with when they are together. This is their most recents, and in my opinion best album, that the duo has released before havig the opportunity to work on their own individual projects. We await the day the duo reunites for another great album!

# %% [markdown]
# Users of Spotify are the originators of the data. Spotify are the collectors and curators of the data.

# %%
import requests
import base64
import six
import json
import pandas as pd

# %%
tokens = pd.read_csv('Spotify_Keys.txt', sep = ',', header = None)
tokens.columns = tokens.iloc[0]
tokens = tokens[1:]
#tokens.Client_Secret[1]

# %%
def start_session_headers(client_id, client_secret):
    client_cred = base64.b64encode(six.text_type(client_id + ":" + client_secret).encode("ascii"))
    headers = {"Authorization": "Basic %s" % client_cred.decode("ascii")}
    return headers

#print(start_session_headers(tokens.Client_ID[1], tokens.Client_Secret[1]))

# %%
def connect_to_client_cred(url, headers):
    payload = {'grant_type' : 'client_credentials'}
    response = requests.request("POST", url, headers = headers, data = payload)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
def get_access_token():
    url = "https://accounts.spotify.com/api/token"
    header = start_session_headers(tokens.Client_ID[1], tokens.Client_Secret[1])
    json_response = connect_to_client_cred(url, header)
    return json_response

# %%
session_token = get_access_token()
# Out:
# 200

# %%
session_token
# Out:
# {'access_token': 'BQDE9Kbfbfw_Q1p8Xo8tGRRMFtpXwQ4XdNLFdnefJu2oL6o5jqjz4ENukPkRGYCQBKzP6bU5gnjd0pFbqp8fmmN7INh7mredWJ3yYtSJP2GRYvHQ_R8',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
def create_header(session_token):
    headers = {"Authorization": "Bearer {}".format(session_token)}
    return headers

# %%
def connect_to_endpoint(url, headers):
    response =requests.request("GET", url, headers = headers)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
def track_audio_features(id):
    url = 'https://api.spotify.com/v1/audio-features{}'.format(id)
    header = create_header(session_token['access_token'])
    json_response = connect_to_endpoint(url, header)
    return json_response

# %%
def album(id):
    url = 'https://api.spotify.com/v1/albums/{}'.format(id)
    header = create_header(session_token['access_token'])
    json_response = connect_to_endpoint(url, header)
    return json_response

# %%
def several_tracks(id):
    url = 'https://api.spotify.com/v1/audio-features?ids={}'.format(id)
    header = create_header(session_token['access_token'])
    json_response = connect_to_endpoint(url, header)
    return json_response

# %% [markdown]
# # Access All Areas

# %%
aaa_id = "3wSWMuHQOJ2gU22t5sCouR"

# %%
aaa = album(aaa_id)
aaa
# Out:
# 200
# {'album_type': 'album',
#  'total_tracks': 16,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
# ...

# %%
aaa_tracks = several_tracks('3wSWMuHQOJ2gU22t5sCouR')
# Out:
# 200

# %%
aaa_tracks
# Out:
# {'audio_features': [None]}

# %%
aaa_tracks_endpoint = "https://api.spotify.com/v1/albums/{}/tracks".format(aaa_id)
aaa_tracks = requests.get(aaa_tracks_endpoint, headers = session_header)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 aaa_tracks_endpoint = "https://api.spotify.com/v1/albums/{}/tracks".format(aaa_id)
# ----> 2 aaa_tracks = requests.get(aaa_tracks_endpoint, headers = session_header)
#
# NameError: name 'session_header' is not defined
