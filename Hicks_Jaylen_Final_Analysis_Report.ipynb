# %% [markdown]
# # Jaylen Hicks
# ## Final Report
# ### December 10, 2024

# %% [markdown]
# Marvel Studios is the highest-grossing film series of all time. They have produced over 34 films and have built massive universes combined through a central multiverse. Each film uses a sleuth of superhero characters and supero villians to tell an intertwining story within the various worlds in the Marvel Cinematic Multiverse. While holding prominence in its respective film catagory, Marvel Films tend to face constraints in story: The Bad Guys pose a serious threat. The Good Guys have to win at the end.
#
# Superhero tropes and story constraints limit the originality that a story can bring. Some Marvel fans have caught on to the central trends, themes, and tropes of the story. Some viewers complain that Marvel movies don't feel fresh or new, and more recycled.
#
# Have Marvel Films have lost favor over years? To determine this, I want to take all the Marvel Films with at least three films in its sequence. Using box office performance as a metric to determine the success of a movie, I can see if each film was more or less successful as the time goes on.
#
# #### Hypothesis:
# Due to recycled storylines, superhero tropes, and story constraints, I believe that Marvel Movies have fallen out of love with fans of the Marvel Cinematic Universe, reducing the success in the box office with each release in a film sequence. For this project, I believe the the Highest Grossing, First Series, and Most Recent Series of Movies to Analyze will give the greatest outlook on how these movies have performed as time passed.
#
# Data Source: TMDB: The Movie DataBase is a website where users can rank and give opionions about films they've recently seen. Information about various films is curated and stored on this website.

# %%
import requests
import base64
import six
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJjNjI4YjAwOGQxODllNmIwZTgwZTgwZTU2OTgxNWVlYSIsIm5iZiI6MTczMjM4NjI1Mi4wNDcxNjU0LCJzdWIiOiI2NzQyMWQyMDdiODI1ZTY4NWI0ZTY1ODUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.tLFCB56hri3IvH_2lFKNIaS4ZEODf0mmIxbIgW-vVC4"
}

# %% [markdown]
# ## Venom Series 2021-Present

# %%
Venom_1 = "https://api.themoviedb.org/3/movie/335983?language=en-US"
response = requests.get(Venom_1, headers=headers)
print(response.text)
Venom_1= response.text
# Out:
# {"adult":false,"backdrop_path":"/VuukZLgaCrho2Ar8Scl9HtV3yD.jpg","belongs_to_collection":{"id":558216,"name":"Venom Collection","poster_path":"/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg","backdrop_path":"/vq340s8DxA5Q209FT8PHA6CXYOx.jpg"},"budget":116000000,"genres":[{"id":878,"name":"Science Fiction"},{"id":28,"name":"Action"}],"homepage":"https://www.sonypictures.com/movies/venom","id":335983,"imdb_id":"tt1270797","origin_country":["US"],"original_language":"en","original_title":"Venom","overview":"Investigative journalist Eddie Brock attempts a comeback following a scandal, but accidentally becomes the host of Venom, a violent, super powerful alien symbiote. Soon, he must rely on his newfound powers to protect the world from a shadowy organization looking for a symbiote of their own.","popularity":301.84,"poster_path":"/2uNW4WbgBXL25BAbXGLnLqX71Sw.jpg","production_companies":[{"id":53462,"logo_path":"/nx8B3Phlcse02w86RW4CJqzCnfL.png","name":"Matt Tolmach Productions","origin_country":"US"},
# ...

# %%
Venom_1 = {
    "adult": False,
    "backdrop_path": "/VuukZLgaCrho2Ar8Scl9HtV3yD.jpg",
    "belongs_to_collection": {
        "id": 558216,
        "name": "Venom Collection",
        "poster_path": "/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg",
        "backdrop_path": "/vq340s8DxA5Q209FT8PHA6CXYOx.jpg"
    },
    "budget": 116000000,
    "genres": [{"id": 878, "name": "Science Fiction"}, {"id": 28, "name": "Action"}],
    "homepage": "https://www.sonypictures.com/movies/venom",
    "id": 335983,
    "imdb_id": "tt1270797",
    "origin_country": ["US"],
    "original_language": "en",
    "original_title": "Venom",
    "overview": "Investigative journalist Eddie Brock attempts a comeback following a scandal, but accidentally becomes the host of Venom, a violent, super powerful alien symbiote. Soon, he must rely on his newfound powers to protect the world from a shadowy organization looking for a symbiote of their own.",
    "popularity": 301.84,
    "poster_path": "/2uNW4WbgBXL25BAbXGLnLqX71Sw.jpg",
    "production_companies": [
        {"id": 53462, "logo_path": "/nx8B3Phlcse02w86RW4CJqzCnfL.png", "name": "Matt Tolmach Productions", "origin_country": "US"},
        {"id": 84041, "logo_path": "/nw4kyc29QRpNtFbdsBHkRSFavvt.png", "name": "Pascal Pictures", "origin_country": "US"},
        {"id": 7505, "logo_path": "/837VMM4wOkODc1idNxGT0KQJlej.png", "name": "Marvel Entertainment", "origin_country": "US"},
        {"id": 81620, "logo_path": "/7LkIVuWBVScdujpKhBPx1TMnPQE.png", "name": "Tencent Pictures", "origin_country": "CN"},
        {"id": 14439, "logo_path": None, "name": "Arad Productions", "origin_country": "US"},
        {"id": 5, "logo_path": "/71BqEFAF4V3qjjMPCpLuyJFB9A.png", "name": "Columbia Pictures", "origin_country": "US"}
    ],
    "production_countries": [
        {"iso_3166_1": "CN", "name": "China"},
        {"iso_3166_1": "US", "name": "United States of America"}
    ],
    "release_date": "2018-09-28",
    "revenue": 856085151,
    "runtime": 112,
    "spoken_languages": [
        {"english_name": "Mandarin", "iso_639_1": "zh", "name": "普通话"},
        {"english_name": "English", "iso_639_1": "en", "name": "English"},
        {"english_name": "Malay", "iso_639_1": "ms", "name": "Bahasa melayu"}
    ],
    "status": "Released",
    "tagline": "The world has enough Superheroes.",
    "title": "Venom",
    "video": False,
    "vote_average": 6.8,
    "vote_count": 16066
}

budget = Venom_1['budget']
revenue = Venom_1['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['black', 'red'])
plt.title('Budget vs Revenue for the First Venom Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %%
Venom_2 = "https://api.themoviedb.org/3/movie/580489?language=en-US"
response = requests.get(Venom_2, headers=headers)
print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg","belongs_to_collection":{"id":558216,"name":"Venom Collection","poster_path":"/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg","backdrop_path":"/vq340s8DxA5Q209FT8PHA6CXYOx.jpg"},"budget":110000000,"genres":[{"id":878,"name":"Science Fiction"},{"id":28,"name":"Action"},{"id":12,"name":"Adventure"}],"homepage":"https://www.venom.movie","id":580489,"imdb_id":"tt7097896","origin_country":["US"],"original_language":"en","original_title":"Venom: Let There Be Carnage","overview":"After finding a host body in investigative reporter Eddie Brock, the alien symbiote must face a new enemy, Carnage, the alter ego of serial killer Cletus Kasady.","popularity":341.095,"poster_path":"/1MJNcPZy46hIy2CmSqOeru0yr5C.jpg","production_companies":[{"id":5,"logo_path":"/71BqEFAF4V3qjjMPCpLuyJFB9A.png","name":"Columbia Pictures","origin_country":"US"},{"id":84041,"logo_path":"/nw4kyc29QRpNtFbdsBHkRSFavvt.png","name":"Pascal Pictures","origin_country":"US"},
# ...

# %%
Venom_2 = {
    "adult": False,
    "backdrop_path": "/vIgyYkXkg6NC2whRbYjBD7eb3Er.jpg",
    "belongs_to_collection": {
        "id": 558216,
        "name": "Venom Collection",
        "poster_path": "/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg",
        "backdrop_path": "/vq340s8DxA5Q209FT8PHA6CXYOx.jpg"
    },
    "budget": 110000000,
    "genres": [
        {"id": 878, "name": "Science Fiction"},
        {"id": 28, "name": "Action"},
        {"id": 12, "name": "Adventure"}
    ],
    "homepage": "https://www.venom.movie",
    "id": 580489,
    "imdb_id": "tt7097896",
    "origin_country": ["US"],
    "original_language": "en",
    "original_title": "Venom: Let There Be Carnage",
    "overview": "After finding a host body in investigative reporter Eddie Brock, the alien symbiote must face a new enemy, Carnage, the alter ego of serial killer Cletus Kasady.",
    "popularity": 341.095,
    "poster_path": "/1MJNcPZy46hIy2CmSqOeru0yr5C.jpg",
    "production_companies": [
        {"id": 5, "logo_path": "/71BqEFAF4V3qjjMPCpLuyJFB9A.png", "name": "Columbia Pictures", "origin_country": "US"},
        {"id": 84041, "logo_path": "/nw4kyc29QRpNtFbdsBHkRSFavvt.png", "name": "Pascal Pictures", "origin_country": "US"},
        {"id": 53462, "logo_path": "/nx8B3Phlcse02w86RW4CJqzCnfL.png", "name": "Matt Tolmach Productions", "origin_country": "US"},
        {"id": 14439, "logo_path": None, "name": "Arad Productions", "origin_country": "US"}
    ],
    "production_countries": [{"iso_3166_1": "US", "name": "United States of America"}],
    "release_date": "2021-09-30",
    "revenue": 506863592,
    "runtime": 97,
    "spoken_languages": [
        {"english_name": "English", "iso_639_1": "en", "name": "English"},
        {"english_name": "Spanish", "iso_639_1": "es", "name": "Español"}
    ],
    "status": "Released",
    "tagline": "It’s time to meet Carnage.",
    "title": "Venom: Let There Be Carnage",
    "video": False,
    "vote_average": 6.8,
    "vote_count": 10268
}

# Accessing data
budget = Venom_2['budget']
revenue = Venom_2['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['black', 'red'])
plt.title('Budget vs Revenue for The Second Venom Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %%
Venom_3 = "https://api.themoviedb.org/3/movie/912649?language=en-US"
response = requests.get(Venom_3, headers=headers)
print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg","belongs_to_collection":{"id":558216,"name":"Venom Collection","poster_path":"/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg","backdrop_path":"/vq340s8DxA5Q209FT8PHA6CXYOx.jpg"},"budget":120000000,"genres":[{"id":28,"name":"Action"},{"id":878,"name":"Science Fiction"},{"id":12,"name":"Adventure"}],"homepage":"https://venom.movie","id":912649,"imdb_id":"tt16366836","origin_country":["US"],"original_language":"en","original_title":"Venom: The Last Dance","overview":"Eddie and Venom are on the run. Hunted by both of their worlds and with the net closing in, the duo are forced into a devastating decision that will bring the curtains down on Venom and Eddie's last dance.","popularity":12656.263,"poster_path":"/aosm8NMQ3UyoBVpSxyimorCQykC.jpg","production_companies":[{"id":5,"logo_path":"/71BqEFAF4V3qjjMPCpLuyJFB9A.png","name":"Columbia Pictures","origin_country":"US"},{"id":84041,"logo_path":"/nw4kyc29QRpNtFbdsBHkRSFavvt.png","name":"Pas
# ...

# %%
Venom_3={
  "adult": False,
  "backdrop_path": "/3V4kLQg0kSqPLctI5ziYWabAZYF.jpg",
  "belongs_to_collection": {
    "id": 558216,
    "name": "Venom Collection",
    "poster_path": "/4bXIKqdZIjR8wKgZaGDaLhLj4yF.jpg",
    "backdrop_path": "/vq340s8DxA5Q209FT8PHA6CXYOx.jpg"
  },
  "budget": 120000000,
  "genres": [
    {
      "id": 28,
      "name": "Action"
    },
    {
      "id": 878,
      "name": "Science Fiction"
    },
    {
      "id": 12,
      "name": "Adventure"
    }
  ],
  "homepage": "https://venom.movie",
  "id": 912649,
  "imdb_id": "tt16366836",
  "origin_country": [
    "US"
  ],
  "original_language": "en",
  "original_title": "Venom: The Last Dance",
  "overview": "Eddie and Venom are on the run. Hunted by both of their worlds and with the net closing in, the duo are forced into a devastating decision that will bring the curtains down on Venom and Eddie's last dance.",
  "popularity": 12656.263,
  "poster_path": "/aosm8NMQ3UyoBVpSxyimorCQykC.jpg",
  "production_companies": [
    {
      "id": 5,
      "logo_path": "/71BqEFAF4V3qjjMPCpLuyJFB9A.png",
      "name": "Columbia Pictures",
      "origin_country": "US"
    },
    {
      "id": 84041,
      "logo_path": "/nw4kyc29QRpNtFbdsBHkRSFavvt.png",
      "name": "Pascal Pictures",
      "origin_country": "US"
    },
    {
      "id": 53462,
      "logo_path": "/nx8B3Phlcse02w86RW4CJqzCnfL.png",
      "name": "Matt Tolmach Productions",
      "origin_country": "US"
    },
    {
      "id": 91797,
      "name": "Hutch Parker Entertainment",
      "origin_country": "US"
    },
    {
      "id": 14439,
      "name": "Arad Productions",
      "origin_country": "US"
    }
  ],
  "production_countries": [
    {
      "iso_3166_1": "US",
      "name": "United States of America"
    }
  ],
  "release_date": "2024-10-22",
  "revenue": 468513700,
  "runtime": 109,
  "spoken_languages": [
    {
      "english_name": "English",
      "iso_639_1": "en",
      "name": "English"
    }
  ],
  "status": "Released",
  "tagline": "'Til death do they part.",
  "title": "Venom: The Last Dance",
  "video": False,
  "vote_average": 6.6,
  "vote_count": 1128
}

# Accessing data
budget = Venom_3['budget']
revenue = Venom_3['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['black', 'red'])
plt.title('Budget vs Revenue for the Third Venom Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %%
venrevenue = Venom_1['revenue']
venrevenue1 = Venom_2['revenue']
venrevenue2 = Venom_3['revenue']

categories = ['First', 'Second', 'Third']
values = [revenue, revenue1, revenue2]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['red', 'black'])
plt.title('Venom Box Office Comparison', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Movies', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %% [markdown]
# This chart proves the claim of my hypothesis, that there has been an decline in the performance in the box office for this film. It started off grossing over 850 million with the first movie. The most recent film only grossed 506 million in the box office. Having seen all three movies, the central themes of the film are similar. I believe viewers have are beginning to realize this and have stopped showing up to see the film in theaters.

# %% [markdown]
# ## Iron Man 2008-2013

# %%
Iron_Man = "https://api.themoviedb.org/3/movie/1726?language=en-US"
response = requests.get(Iron_Man, headers=headers)
print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/cyecB7godJ6kNHGONFjUyVN9OX5.jpg","belongs_to_collection":{"id":131292,"name":"Iron Man Collection","poster_path":"/fbeJ7f0aD4A112Bc1tnpzyn82xO.jpg","backdrop_path":"/rI8zOWkRQJdlAyQ6WJOSlYK6JxZ.jpg"},"budget":140000000,"genres":[{"id":28,"name":"Action"},{"id":878,"name":"Science Fiction"},{"id":12,"name":"Adventure"}],"homepage":"https://www.marvel.com/movies/iron-man","id":1726,"imdb_id":"tt0371746","origin_country":["US"],"original_language":"en","original_title":"Iron Man","overview":"After being held captive in an Afghan cave, billionaire engineer Tony Stark creates a unique weaponized suit of armor to fight evil.","popularity":92.993,"poster_path":"/78lPtwv72eTNqFW9COBYI0dWDJa.jpg","production_companies":[{"id":420,"logo_path":"/hUzeosd33nzE5MCNsZxCGEKTXaQ.png","name":"Marvel Studios","origin_country":"US"},{"id":7505,"logo_path":"/837VMM4wOkODc1idNxGT0KQJlej.png","name":"Marvel Entertainment","origin_country":"US"},{"id":7297,"logo_path":"/l29J
# ...

# %%
Iron_Man= {"adult":False,"backdrop_path":"/cyecB7godJ6kNHGONFjUyVN9OX5.jpg","belongs_to_collection":{"id":131292,"name":"Iron Man Collection","poster_path":"/fbeJ7f0aD4A112Bc1tnpzyn82xO.jpg","backdrop_path":"/rI8zOWkRQJdlAyQ6WJOSlYK6JxZ.jpg"},"budget":140000000,"genres":[{"id":28,"name":"Action"},{"id":878,"name":"Science Fiction"},{"id":12,"name":"Adventure"}],"homepage":"https://www.marvel.com/movies/iron-man","id":1726,"imdb_id":"tt0371746","origin_country":["US"],"original_language":"en","original_title":"Iron Man","overview":"After being held captive in an Afghan cave, billionaire engineer Tony Stark creates a unique weaponized suit of armor to fight evil.","popularity":92.993,"poster_path":"/78lPtwv72eTNqFW9COBYI0dWDJa.jpg","production_companies":[{"id":420,"logo_path":"/hUzeosd33nzE5MCNsZxCGEKTXaQ.png","name":"Marvel Studios","origin_country":"US"},{"id":7505,"logo_path":"/837VMM4wOkODc1idNxGT0KQJlej.png","name":"Marvel Entertainment","origin_country":"US"},{"id":7297,"logo_path":"/l29JYQVZbTcjZXoz4CUYFpKRmM3.png","name":"Fairview Entertainment","origin_country":"US"}],"production_countries":[{"iso_3166_1":"US","name":"United States of America"}],"release_date":"2008-04-30","revenue":585174222,"runtime":126,"spoken_languages":[{"english_name":"English","iso_639_1":"en","name":"English"},{"english_name":"Persian","iso_639_1":"fa","name":"فارسی"},{"english_name":"Urdu","iso_639_1":"ur","name":"اردو"},{"english_name":"Arabic","iso_639_1":"ar","name":"العربية"}],"status":"Released","tagline":"Heroes aren't born. They're built.","title":"Iron Man","video":False,"vote_average":7.647,"vote_count":26377}

# %%
Iron_Man_2 = "https://api.themoviedb.org/3/movie/10138?language=en-US"
response = requests.get(Iron_Man_2, headers=headers)
print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/7lmBufEG7P7Y1HClYK3gCxYrkgS.jpg","belongs_to_collection":{"id":131292,"name":"Iron Man Collection","poster_path":"/fbeJ7f0aD4A112Bc1tnpzyn82xO.jpg","backdrop_path":"/rI8zOWkRQJdlAyQ6WJOSlYK6JxZ.jpg"},"budget":200000000,"genres":[{"id":12,"name":"Adventure"},{"id":28,"name":"Action"},{"id":878,"name":"Science Fiction"}],"homepage":"https://www.marvel.com/movies/iron-man-2","id":10138,"imdb_id":"tt1228705","origin_country":["US"],"original_language":"en","original_title":"Iron Man 2","overview":"With the world now aware of his dual life as the armored superhero Iron Man, billionaire inventor Tony Stark faces pressure from the government, the press and the public to share his technology with the military. Unwilling to let go of his invention, Stark, with Pepper Potts and James 'Rhodey' Rhodes at his side, must forge new alliances – and confront powerful enemies.","popularity":79.459,"poster_path":"/6WBeq4fCfn7AN0o21W9qNcRF2l9.jpg","production_companies":
# ...

# %%
budget = Iron_Man['budget']
revenue = Iron_Man['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['red', 'gold'])
plt.title('Budget vs Revenue for the First Iron Man Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %%
Iron_Man_3 = "https://api.themoviedb.org/3/movie/68721?language=en-US"
response = requests.get(Iron_Man_3, headers=headers)
print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/iVped1djsF0tvGkvnHbzsE3ZPTF.jpg","belongs_to_collection":{"id":131292,"name":"Iron Man Collection","poster_path":"/fbeJ7f0aD4A112Bc1tnpzyn82xO.jpg","backdrop_path":"/rI8zOWkRQJdlAyQ6WJOSlYK6JxZ.jpg"},"budget":200000000,"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":878,"name":"Science Fiction"}],"homepage":"https://www.marvel.com/movies/iron-man-3","id":68721,"imdb_id":"tt1300854","origin_country":["US"],"original_language":"en","original_title":"Iron Man 3","overview":"When Tony Stark's world is torn apart by a formidable terrorist called the Mandarin, he starts an odyssey of rebuilding and retribution.","popularity":89.501,"poster_path":"/qhPtAc1TKbMPqNvcdXSOn9Bn7hZ.jpg","production_companies":[{"id":420,"logo_path":"/hUzeosd33nzE5MCNsZxCGEKTXaQ.png","name":"Marvel Studios","origin_country":"US"}],"production_countries":[{"iso_3166_1":"US","name":"United States of America"}],"release_date":"2013-04-18","revenue":1215577205,"r
# ...

# %%
Iron_Man_2 = {"adult":False,"backdrop_path":"/7lmBufEG7P7Y1HClYK3gCxYrkgS.jpg","belongs_to_collection":{"id":131292,"name":"Iron Man Collection","poster_path":"/fbeJ7f0aD4A112Bc1tnpzyn82xO.jpg","backdrop_path":"/rI8zOWkRQJdlAyQ6WJOSlYK6JxZ.jpg"},"budget":200000000,"genres":[{"id":12,"name":"Adventure"},{"id":28,"name":"Action"},{"id":878,"name":"Science Fiction"}],"homepage":"https://www.marvel.com/movies/iron-man-2","id":10138,"imdb_id":"tt1228705","origin_country":["US"],"original_language":"en","original_title":"Iron Man 2","overview":"With the world now aware of his dual life as the armored superhero Iron Man, billionaire inventor Tony Stark faces pressure from the government, the press and the public to share his technology with the military. Unwilling to let go of his invention, Stark, with Pepper Potts and James 'Rhodey' Rhodes at his side, must forge new alliances – and confront powerful enemies.","popularity":79.459,"poster_path":"/6WBeq4fCfn7AN0o21W9qNcRF2l9.jpg","production_companies":[{"id":420,"logo_path":"/hUzeosd33nzE5MCNsZxCGEKTXaQ.png","name":"Marvel Studios","origin_country":"US"},{"id":7297,"logo_path":"/l29JYQVZbTcjZXoz4CUYFpKRmM3.png","name":"Fairview Entertainment","origin_country":"US"},{"id":7505,"logo_path":"/837VMM4wOkODc1idNxGT0KQJlej.png","name":"Marvel Entertainment","origin_country":"US"}],"production_countries":[{"iso_3166_1":"US","name":"United States of America"}],"release_date":"2010-04-28","revenue":623933331,"runtime":124,"spoken_languages":[{"english_name":"English","iso_639_1":"en","name":"English"},{"english_name":"Russian","iso_639_1":"ru","name":"Pусский"},{"english_name":"French","iso_639_1":"fr","name":"Français"}],"status":"Released","tagline":"It's not the armor that makes the hero, but the man inside.","title":"Iron Man 2","video":False,"vote_average":6.8,"vote_count":20958}

# %%
budget = Iron_Man_2['budget']
revenue = Iron_Man_2['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['red', 'gold'])
plt.title('Budget vs Revenue for the Second Iron Man Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %%
Iron_Man_3 = {"adult":False,"backdrop_path":"/iVped1djsF0tvGkvnHbzsE3ZPTF.jpg","belongs_to_collection":{"id":131292,"name":"Iron Man Collection","poster_path":"/fbeJ7f0aD4A112Bc1tnpzyn82xO.jpg","backdrop_path":"/rI8zOWkRQJdlAyQ6WJOSlYK6JxZ.jpg"},"budget":200000000,"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":878,"name":"Science Fiction"}],"homepage":"https://www.marvel.com/movies/iron-man-3","id":68721,"imdb_id":"tt1300854","origin_country":["US"],"original_language":"en","original_title":"Iron Man 3","overview":"When Tony Stark's world is torn apart by a formidable terrorist called the Mandarin, he starts an odyssey of rebuilding and retribution.","popularity":89.501,"poster_path":"/qhPtAc1TKbMPqNvcdXSOn9Bn7hZ.jpg","production_companies":[{"id":420,"logo_path":"/hUzeosd33nzE5MCNsZxCGEKTXaQ.png","name":"Marvel Studios","origin_country":"US"}],"production_countries":[{"iso_3166_1":"US","name":"United States of America"}],"release_date":"2013-04-18","revenue":1215577205,"runtime":130,"spoken_languages":[{"english_name":"English","iso_639_1":"en","name":"English"}],"status":"Released","tagline":"Unleash the power behind the armor.","title":"Iron Man 3","video":False,"vote_average":6.931,"vote_count":22143}

# %%
budget = Iron_Man_3['budget']
revenue = Iron_Man_3['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['red', 'gold'])
plt.title('Budget vs Revenue for the Third Iron Man Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %%
revenue = Iron_Man['revenue']
revenue1 = Iron_Man_2['revenue']
revenue2 = Iron_Man_3['revenue']

categories = ['First', 'Second', 'Third']
values = [revenue, revenue1, revenue2]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['red', 'gold'])
plt.title('Iron Man Box Office Comparison', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Movies', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %% [markdown]
# The Iron Man films were the first of the movies that Marvel Produced! With each new release, these films have gotten more popular. These figures seem to disprove my claim as the last Iron Man film did almost twice as well as the first.

# %% [markdown]
# ## Avengers 2012-Present

# %%
Avengers_1 = "https://api.themoviedb.org/3/movie/24428?language=en-US"
response = requests.get(Avengers_1, headers=headers)
print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg","belongs_to_collection":{"id":86311,"name":"The Avengers Collection","poster_path":"/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg","backdrop_path":"/zuW6fOiusv4X9nnW3paHGfXcSll.jpg"},"budget":220000000,"genres":[{"id":878,"name":"Science Fiction"},{"id":28,"name":"Action"},{"id":12,"name":"Adventure"}],"homepage":"https://www.marvel.com/movies/the-avengers","id":24428,"imdb_id":"tt0848228","origin_country":["US"],"original_language":"en","original_title":"The Avengers","overview":"When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!","popularity":119.893,"poster_path":"/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg","production_companies":[{"id":420,"logo_path":"/hUzeosd33nzE5MCNsZxCGEKTXaQ.png","name":"Ma
# ...

# %%
Avengers_1 ={ "adult":False,"backdrop_path":"/9BBTo63ANSmhC4e6r62OJFuK2GL.jpg","belongs_to_collection":{"id":86311,"name":"The Avengers Collection","poster_path":"/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg","backdrop_path":"/zuW6fOiusv4X9nnW3paHGfXcSll.jpg"},"budget":220000000,"genres":[{"id":878,"name":"Science Fiction"},{"id":28,"name":"Action"},{"id":12,"name":"Adventure"}],"homepage":"https://www.marvel.com/movies/the-avengers","id":24428,"imdb_id":"tt0848228","origin_country":["US"],"original_language":"en","original_title":"The Avengers","overview":"When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director of the international peacekeeping agency known as S.H.I.E.L.D., finds himself in need of a team to pull the world back from the brink of disaster. Spanning the globe, a daring recruitment effort begins!","popularity":119.893,"poster_path":"/RYMX2wcKCBAr24UyPD7xwmjaTn.jpg","production_companies":[{"id":420,"logo_path":"/hUzeosd33nzE5MCNsZxCGEKTXaQ.png","name":"Marvel Studios","origin_country":"US"}],"production_countries":[{"iso_3166_1":"US","name":"United States of America"}],"release_date":"2012-04-25","revenue":1518815515,"runtime":143,"spoken_languages":[{"english_name":"English","iso_639_1":"en","name":"English"},{"english_name":"Hindi","iso_639_1":"hi","name":"हिन्दी"},{"english_name":"Russian","iso_639_1":"ru","name":"Pусский"}],"status":"Released","tagline":"Some assembly required.","title":"The Avengers","video":False,"vote_average":7.723,"vote_count":30817}

# %%
budget = Avengers_1['budget']
revenue = Avengers_1['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['gold', 'purple'])
plt.title('Budget vs Revenue for the First Avengers Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %%
Avengers_2 = "https://api.themoviedb.org/3/movie/99861?language=en-US"
response = requests.get(Avengers_2, headers=headers)
print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/6YwkGolwdOMNpbTOmLjoehlVWs5.jpg","belongs_to_collection":{"id":86311,"name":"The Avengers Collection","poster_path":"/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg","backdrop_path":"/zuW6fOiusv4X9nnW3paHGfXcSll.jpg"},"budget":365000000,"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":878,"name":"Science Fiction"}],"homepage":"http://marvel.com/movies/movie/193/avengers_age_of_ultron","id":99861,"imdb_id":"tt2395427","origin_country":["US"],"original_language":"en","original_title":"Avengers: Age of Ultron","overview":"When Tony Stark tries to jumpstart a dormant peacekeeping program, things go awry and Earth’s Mightiest Heroes are put to the ultimate test as the fate of the planet hangs in the balance. As the villainous Ultron emerges, it is up to The Avengers to stop him from enacting his terrible plans, and soon uneasy alliances and unexpected action pave the way for an epic and unique global adventure.","popularity":81.493,"poster_path":"/4
# ...

# %%
Avengers_2 = {"adult":False,"backdrop_path":"/6YwkGolwdOMNpbTOmLjoehlVWs5.jpg","belongs_to_collection":{"id":86311,"name":"The Avengers Collection","poster_path":"/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg","backdrop_path":"/zuW6fOiusv4X9nnW3paHGfXcSll.jpg"},"budget":365000000,"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":878,"name":"Science Fiction"}],"homepage":"http://marvel.com/movies/movie/193/avengers_age_of_ultron","id":99861,"imdb_id":"tt2395427","origin_country":["US"],"original_language":"en","original_title":"Avengers: Age of Ultron","overview":"When Tony Stark tries to jumpstart a dormant peacekeeping program, things go awry and Earth’s Mightiest Heroes are put to the ultimate test as the fate of the planet hangs in the balance. As the villainous Ultron emerges, it is up to The Avengers to stop him from enacting his terrible plans, and soon uneasy alliances and unexpected action pave the way for an epic and unique global adventure.","popularity":81.493,"poster_path":"/4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg","production_companies":[{"id":420,"logo_path":"/hUzeosd33nzE5MCNsZxCGEKTXaQ.png","name":"Marvel Studios","origin_country":"US"}],"production_countries":[{"iso_3166_1":"US","name":"United States of America"}],"release_date":"2015-04-22","revenue":1405403694,"runtime":141,"spoken_languages":[{"english_name":"English","iso_639_1":"en","name":"English"}],"status":"Released","tagline":"A new age has come.","title":"Avengers: Age of Ultron","video":False,"vote_average":7.274,"vote_count":22965}

# %%
budget = Avengers_2['budget']
revenue = Avengers_2['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['gold', 'purple'])
plt.title('Budget vs Revenue for the Second Avengers Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %%
Avengers_3 = "https://api.themoviedb.org/3/movie/299536?language=en-US"
response = requests.get(Avengers_3, headers=headers)
print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg","belongs_to_collection":{"id":86311,"name":"The Avengers Collection","poster_path":"/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg","backdrop_path":"/zuW6fOiusv4X9nnW3paHGfXcSll.jpg"},"budget":300000000,"genres":[{"id":12,"name":"Adventure"},{"id":28,"name":"Action"},{"id":878,"name":"Science Fiction"}],"homepage":"https://www.marvel.com/movies/avengers-infinity-war","id":299536,"imdb_id":"tt4154756","origin_country":["US"],"original_language":"en","original_title":"Avengers: Infinity War","overview":"As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle, a new danger has emerged from the cosmic shadows: Thanos. A despot of intergalactic infamy, his goal is to collect all six Infinity Stones, artifacts of unimaginable power, and use them to inflict his twisted will on all of reality. Everything the Avengers have fought for has led up to this moment - the fate of Earth 
# ...

# %%
Avengers_3 = {"adult":False,"backdrop_path":"/mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg","belongs_to_collection":{"id":86311,"name":"The Avengers Collection","poster_path":"/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg","backdrop_path":"/zuW6fOiusv4X9nnW3paHGfXcSll.jpg"},"budget":300000000,"genres":[{"id":12,"name":"Adventure"},{"id":28,"name":"Action"},{"id":878,"name":"Science Fiction"}],"homepage":"https://www.marvel.com/movies/avengers-infinity-war","id":299536,"imdb_id":"tt4154756","origin_country":["US"],"original_language":"en","original_title":"Avengers: Infinity War","overview":"As the Avengers and their allies have continued to protect the world from threats too large for any one hero to handle, a new danger has emerged from the cosmic shadows: Thanos. A despot of intergalactic infamy, his goal is to collect all six Infinity Stones, artifacts of unimaginable power, and use them to inflict his twisted will on all of reality. Everything the Avengers have fought for has led up to this moment - the fate of Earth and existence itself has never been more uncertain.","popularity":342.224,"poster_path":"/7WsyChQLEftFiDOVTGkv3hFpyyt.jpg","production_companies":[{"id":420,"logo_path":"/hUzeosd33nzE5MCNsZxCGEKTXaQ.png","name":"Marvel Studios","origin_country":"US"}],"production_countries":[{"iso_3166_1":"US","name":"United States of America"}],"release_date":"2018-04-25","revenue":2052415039,"runtime":149,"spoken_languages":[{"english_name":"English","iso_639_1":"en","name":"English"},{"english_name":"Xhosa","iso_639_1":"xh","name":""}],"status":"Released","tagline":"An entire universe. Once and for all.","title":"Avengers: Infinity War","video":False,"vote_average":8.2,"vote_count":29791}

# %%
budget = Avengers_3['budget']
revenuae = Avengers_3['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['gold', 'purple'])
plt.title('Budget vs Revenue for the Third Avengers Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %%
Avengers_4 = "https://api.themoviedb.org/3/movie/299534?language=en-US"
response = requests.get(Avengers_4, headers=headers)
print(response.text)
# Out:
# {"adult":false,"backdrop_path":"/7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg","belongs_to_collection":{"id":86311,"name":"The Avengers Collection","poster_path":"/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg","backdrop_path":"/zuW6fOiusv4X9nnW3paHGfXcSll.jpg"},"budget":356000000,"genres":[{"id":12,"name":"Adventure"},{"id":878,"name":"Science Fiction"},{"id":28,"name":"Action"}],"homepage":"https://www.marvel.com/movies/avengers-endgame","id":299534,"imdb_id":"tt4154796","origin_country":["US"],"original_language":"en","original_title":"Avengers: Endgame","overview":"After the devastating events of Avengers: Infinity War, the universe is in ruins due to the efforts of the Mad Titan, Thanos. With the help of remaining allies, the Avengers must assemble once more in order to undo Thanos' actions and restore order to the universe once and for all, no matter what consequences may be in store.","popularity":124.211,"poster_path":"/or06FN3Dka5tukK1e9sl16pB3iy.jpg","production_companies":[{"id":420,"logo_path":"/hU
# ...

# %%
Avengers_4 = {"adult":False,"backdrop_path":"/7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg","belongs_to_collection":{"id":86311,"name":"The Avengers Collection","poster_path":"/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg","backdrop_path":"/zuW6fOiusv4X9nnW3paHGfXcSll.jpg"},"budget":356000000,"genres":[{"id":12,"name":"Adventure"},{"id":878,"name":"Science Fiction"},{"id":28,"name":"Action"}],"homepage":"https://www.marvel.com/movies/avengers-endgame","id":299534,"imdb_id":"tt4154796","origin_country":["US"],"original_language":"en","original_title":"Avengers: Endgame","overview":"After the devastating events of Avengers: Infinity War, the universe is in ruins due to the efforts of the Mad Titan, Thanos. With the help of remaining allies, the Avengers must assemble once more in order to undo Thanos' actions and restore order to the universe once and for all, no matter what consequences may be in store.","popularity":124.211,"poster_path":"/or06FN3Dka5tukK1e9sl16pB3iy.jpg","production_companies":[{"id":420,"logo_path":"/hUzeosd33nzE5MCNsZxCGEKTXaQ.png","name":"Marvel Studios","origin_country":"US"}],"production_countries":[{"iso_3166_1":"US","name":"United States of America"}],"release_date":"2019-04-24","revenue":2799439100,"runtime":181,"spoken_languages":[{"english_name":"English","iso_639_1":"en","name":"English"},{"english_name":"Japanese","iso_639_1":"ja","name":"日本語"},{"english_name":"Xhosa","iso_639_1":"xh","name":""}],"status":"Released","tagline":"Avenge the fallen.","title":"Avengers: Endgame","video":False,"vote_average":8.2,"vote_count":25662}

# %%
budget = Avengers_4['budget']
revenuae = Avengers_4['revenue']

categories = ['Budget', 'Revenue']
values = [budget, revenue]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['gold', 'purple'])
plt.title('Budget vs Revenue for the Third Avengers Movie', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Category', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %%
avrevenue = Avengers_1['revenue']
avrevenue1 = Avengers_2['revenue']
avrevenue2 = Avengers_3['revenue']
avrevenue3 = Avengers_4['revenue']

categories = ['First', 'Second', 'Third', 'Fourth']
values = [avrevenue, avrevenue1, avrevenue2, avrevenue3]

plt.figure(figsize=(8, 5))
plt.bar(categories, values, color=['purple', 'gold'])
plt.title('Avengers Box Office Comparison', fontsize=14)
plt.ylabel('Amount (in USD)', fontsize=12)
plt.xlabel('Movies', fontsize=12)

for i, value in enumerate(values):
    plt.text(i, value + 20_000_000, f'${value:,}', ha='center', fontsize=10)

plt.show()

# %% [markdown]
# This film sequence seems to argue against my hypothesis. With the exception of the second Avengers film, they have been doing progressively well in the box office. With the Avengers being the most popular Marvel sequence, it may be that this the popularity of this series outweighs its the tropes often seen in superhero films. This series more unpredictable elements in comparison to other franchises. For this reason, I believe viewers are more excited to see The Avengers Films rather than their Marvel Counterparts.

# %% [markdown]
# # Conclusion
# Venom, the most recent Marvel Series seemed to prove my claim that Marvel Movies are falling out of favor. The first Marvel Franchise saw nearly Double the amount of success than the first movie in the series. I think this was more due to the excitement that viewers had for this series, because these were the first Marvel Superhero movies that were offered. I predict, that if Marvel were to release these films today instead of in the early 2010s, the Iron Man movies would face the same fate of Venom.
#
# With Avengers also doing well in the box office, following similar trends as the first Iron Man. This may go to show that more popular series will have their dedicated fans show up in theaters for the film, other series that dont have these dedicated fanbases may have the same fate as Venom.
#
# Next time, I would compare all the films in the MCU to give me more date, instead of the most popular, first, and most recent. I would also want to compare the films that only have a single movie in its franchise to see if there is any insight to movies that don't have to continue a story or series.
